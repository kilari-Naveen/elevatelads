# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install numpy pandas matplotlib seaborn

# %%
data=pd.read_csv(r"C:\Users\kilar\OneDrive\Desktop\elevate lab\data.csv.csv")
data
# Out:
#      Survived  Pclass       Age  SibSp  Parch      Fare  Sex_male  Embarked_Q  \
# 0           0       3 -0.565736      1      0 -0.502445         1           0
# 1           1       3 -0.258337      0      0 -0.488854         0           0
# 2           1       1  0.433312      1      0  0.420730         0           0
# 3           0       3  0.433312      0      0 -0.486337         1           0
# 4           0       3 -0.104637      0      0 -0.478116         1           1
# ..        ...     ...       ...    ...    ...       ...       ...         ...
# 713         0       2 -0.181487      0      0 -0.386671         1           0
# 714         1       1 -0.796286      0      0 -0.044381         0           0
# 715         0       3 -0.104637      1      2 -0.176263         0           0
# 716         1       1 -0.258337      0      0 -0.044381         1           0
# 717         0       3  0.202762      0      0 -0.492378         1           1
#
#      Embarked_S
# ...

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Age           0
# SibSp         0
# Parch         0
# Fare          0
# Sex_male      0
# Embarked_Q    0
# Embarked_S    0
# dtype: int64

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare  \
# count  718.000000  718.000000  718.000000  718.000000  718.000000  718.000000
# mean     0.334262    2.512535   -0.098537    0.413649    0.317549   -0.302242
# std      0.472061    0.715818    0.769449    0.855001    0.784792    0.266674
# min      0.000000    1.000000   -2.025883    0.000000    0.000000   -0.648422
# 25%      0.000000    2.000000   -0.565736    0.000000    0.000000   -0.489568
# 50%      0.000000    3.000000   -0.104637    0.000000    0.000000   -0.411839
# 75%      1.000000    3.000000    0.270006    1.000000    0.000000   -0.126366
# max      1.000000    3.000000    1.893459    5.000000    6.000000    0.587429
#
#          Sex_male  Embarked_Q  Embarked_S
# count  718.000000  718.000000  718.000000
# mean     0.681058    0.098886    0.756267
# std      0.466391    0.298717    0.429633
# min      0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000
# ...

# %%
print(data.size)
# Out:
# 6462

# %%
data.columns
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_male',
#        'Embarked_Q', 'Embarked_S'],
#       dtype='object')

# %%
print("Summary Statistics:\n")
display(data.describe().T)
# Out:
# Summary Statistics:
#             count      mean       std       min       25%       50%       75%  \
# Survived    718.0  0.334262  0.472061  0.000000  0.000000  0.000000  1.000000
# Pclass      718.0  2.512535  0.715818  1.000000  2.000000  3.000000  3.000000
# Age         718.0 -0.098537  0.769449 -2.025883 -0.565736 -0.104637  0.270006
# SibSp       718.0  0.413649  0.855001  0.000000  0.000000  0.000000  1.000000
# Parch       718.0  0.317549  0.784792  0.000000  0.000000  0.000000  0.000000
# Fare        718.0 -0.302242  0.266674 -0.648422 -0.489568 -0.411839 -0.126366
# Sex_male    718.0  0.681058  0.466391  0.000000  0.000000  1.000000  1.000000
# Embarked_Q  718.0  0.098886  0.298717  0.000000  0.000000  0.000000  0.000000
# Embarked_S  718.0  0.756267  0.429633  0.000000  1.000000  1.000000  1.000000
#
#                  max
# Survived    1.000000
# Pclass      3.000000
# Age         1.893459
# SibSp       5.000000
# Parch       6.000000
# Fare        0.587429
# ...

# %%
numeric_cols = ['Age', 'Fare', 'SibSp', 'Parch']
data[numeric_cols].hist(figsize=(10, 6), bins=20, edgecolor="black")
plt.suptitle("Histograms of Numeric Features")
plt.show()

# %%
numeric_cols = ['Age', 'Fare', 'SibSp', 'Parch']
data[numeric_cols].hist(figsize=(10, 6), bins=20, edgecolor="black")
plt.suptitle("Histograms of Numeric Features")
plt.show()

# %%
plt.figure(figsize=(10, 6))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 2, i)
    sns.boxplot(y=data[col], color="skyblue")
    plt.title(f"Boxplot of {col}")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data.corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
sns.pairplot(data[['Survived', 'Age', 'Fare', 'SibSp', 'Parch']], hue="Survived")
plt.suptitle("Pairplot of Key Features", y=1.02)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x="Pclass", y="Survived", data=data, ci=None)
plt.title("Survival Rate by Passenger Class")
plt.show()

plt.figure(figsize=(8, 5))
sns.barplot(x="Sex_male", y="Survived", data=data, ci=None)
plt.title("Survival Rate by Gender (0=Female, 1=Male)")
plt.show()
# Out:
# C:\Users\kilar\AppData\Local\Temp\ipykernel_22360\3795583483.py:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Pclass", y="Survived", data=data, ci=None)
# C:\Users\kilar\AppData\Local\Temp\ipykernel_22360\3795583483.py:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Sex_male", y="Survived", data=data, ci=None)
